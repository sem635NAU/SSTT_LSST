# %%
import schedule
import time

# %%
def job():
    print("Sending email.")

# schedule.every().monday.at("09:00").do(job)

# while True:
#     schedule.run_pending()
#     time.sleep(1)

# %%
# sender_email = "lsstasteroidupdate@gmail.com"
# recipient_emails = ["sem635@nau.edu"]#, "recipient2@example.com", "recipient3@example.com"]
# password = "Lg>p2!I{[11R" # Use an App Password for Gmail/Outlook for security
# smtp_server = "smtp.example.com" # e.g., "smtp.gmail.com" for Gmail
# smtp_port = 587 # or 465 for SSL

# %%
from email.message import EmailMessage

subject = "Automated Group Email"
body = "This is an automated email sent to a group using Python."

msg = EmailMessage()
msg['From'] = sender_email
msg['To'] = ", ".join(recipient_emails)  # Comma-separated string for display
msg['Subject'] = subject
msg.set_content(body)
# add_attachment(self, *args, **kw)

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication

sender_email = "lsstasteroidupdate@gmail.com"
password = "Lg>p2!I{[11R"

# %%
server = smtplib.SMTP(host="smtp.gmail.com", port=587)
server.starttls()
server.login("lsstasteroidupdate@gmail.com", "Lg>p2!I{[11R")

# msg = MIMEMultipart()
# msg['From'] = sender_email
# msg['To'] = 'sem635@nau.edu'
# msg['Subject'] = 'Testing for email'
# message = 'Test, test, test'
# msg.attach(MIMEText(message, 'plain'))
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[7], line 3
#       1 server = smtplib.SMTP(host="smtp.gmail.com", port=587)
#       2 server.starttls()
# ----> 3 server.login("lsstasteroidupdate@gmail.com", "Lg>p2!I{[11R")
#
# File /packages/anaconda3/2024.02/lib/python3.11/smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File /packages/anaconda3/2024.02/lib/python3.11/smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
# ...

# %%
def mailScheduler():
    s.send_message(msg)

# %%
mail

# %%
import smtplib, ssl

# %%
port = 587
smtp_server = "smtp.gmail.com"
sender_email = "lsstasteroidupdate@gmail.com"
password = ""
receiver_email = "xekin37813@ametitas.com"
message = """\
Subject: Automated email
Body text."""
context = ssl.create_default_context()

with smtplib.SMTP(smtp_server, port) as server:
    server.ehlo()
    server.starttls(context=context)
    server.ehlo()
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)
    # print("Email sent successfully")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[11], line 15
#      13 server.starttls(context=context)
#      14 server.ehlo()
# ---> 15 server.login(sender_email, password)
#      16 server.sendmail(sender_email, receiver_email, message)
#
# File /packages/anaconda3/2024.02/lib/python3.11/smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File /packages/anaconda3/2024.02/lib/python3.11/smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
# ...
